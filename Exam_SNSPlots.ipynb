# %%
import pandas as pd 
import seaborn as sns

# %%
df_exam=pd.read_csv('exams.csv')

# %% [markdown]
# 1.Read the data from the CSVfile into a DataFrame and display the first five rows

# %%
df_exam.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %% [markdown]
# 2.Use the SeaBorn catplot() method to create a plot like the one below.To make that easy to do, you can use a count plot.

# %%
sns.catplot(data=df_exam,kind='count',x='parental level of education',hue='parental level of education')

# %% [markdown]
# 3.Rotate the x labels for the above plot to make them readable.

# %%
ax=sns.countplot(data=df_exam,x='parental level of education',hue='parental level of education')
ax.tick_params('x',labelrotation=45)

# %% [markdown]
# 4.Create a scatterplot with a specific method that compares the writing score with the reading score.
#  Use a different color to show which students took a test prep course.

# %%
sns.scatterplot(data=df_exam,x='writing score'
                ,y='reading score',hue='test preparation course')
# Out:
# <Axes: xlabel='writing score', ylabel='reading score'>

# %% [markdown]
# 5.Create the same plot with a general method.

# %%
sns.relplot(data=df_exam,kind='scatter',
            x='writing score',y='reading score'
            ,hue='test preparation course')

# %% [markdown]
# 6.Adjust the size of the scatter plot you created with the general method so
#  it’s more like the size of the scatter plot with the specific method

# %%
g=sns.relplot(data=df_exam,kind='scatter',
              x='writing score',y='reading score',
              hue='test preparation course',height=6, aspect=1.2)
plt.show()
